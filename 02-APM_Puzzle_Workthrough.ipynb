# %%
# ADVANCED PYTHON MODULES PUZZLE
import shutil

shutil.unpack_archive('unzip_me_for_instructions.zip', 'extracted_content', 'zip')

# %%
import os

os.listdir()
# Out:
# ['Zipping_unzipping.ipynb',
#  'milestone project notes and practice.ipynb',
#  'python statements test solutions again.ipynb',
#  'Untitled55.ipynb',
#  'Untitled10.ipynb',
#  '.zshrc.save',
#  'Untitled7.ipynb',
#  '.config',
#  'Untitled34.ipynb',
#  'final_unzip',
#  'Collections_Module notes.ipynb',
#  'scores.txt',
#  'Music',
#  'Filetwo.txt',
#  'Pip install and pypi.ipynb',
#  'example.zip',
#  'Debugging_Practice.ipynb',
#  'Errors and exceptions notes.ipynb',
#  'Bank_AccountREADME.ipynb',
#  '.condarc',
#  'Timing_your_Python_code.ipynb',
#  'Untitled36.ipynb',
#  'Untitled57.ipynb',
#  'Untitled12.ipynb',
#  'comp_file.zip',
#  'Untitled5.ipynb',
#  'Untitled1.ipynb',
#  'Untitled53.ipynb',
#  'Untitled16.ipynb',
#  '.DS_Store',
#  'nltk_data',
#  'gameTTT.py.txt',
#  'Debugging.ipynb',
#  'maps, lambda, and filter.ipynb',
#  'Untitled32.ipynb',
#  '.CFUserTextEncoding',
#  'Untitled30.ipynb',
#  'Untitled48.ipynb',
#  '.xonshrc',
#  'Regex_notes.ipynb',
# ...

# %%
os.listdir('extracted_content')
# Out:
# ['filetwo.txt', 'fileone.txt', 'extracted_content']

# %%
os.listdir('extracted_content/extracted_content')
# Out:
# ['Instructions.txt', 'Three', 'One', 'Two', 'Five', 'Four']

# %%
with open('extracted_content/extracted_content/Instructions.txt') as f:
    print(f.read())
# Out:
# Good work on unzipping the file!
# You should now see 5 folders, each with a lot of random .txt files.
# Within one of these text files is a telephone number formated ###-###-####
# Use the Python os module and regular expressions to iterate through each file, open it, and search for a telephone number.
# Good luck!

# %%
# test
import re

pattern = r'\d{3}-\d{3}-\d{4}'

test = "random text 123-456-7890 more text 999-000 blah blah blah lol"

re.findall(pattern,test)
# Out:
# ['123-456-7890']

# %%
def search(file_path,pattern):
    with open(file_path,'r') as f:
        text = f.read()
    match = re.search(pattern,text)
    return match


root_folder = 'extracted_content/extracted_content'

results = []

for folder, subfolders, files in os.walk(root_folder):
    for file_name in files:
        file_path = os.path.join(folder,file_name)
        result = search(file_path, pattern)
        if result:
            print("FOUND:", result.group())
# Out:
# FOUND: 719-266-2837

# %%
#test 2 but will fix for loop above once it proves to work
test_path = 'extracted_content/extracted_content/Three/VSXFSTABZDY.txt'
print(search(test_path, pattern))
# Out:
# None
